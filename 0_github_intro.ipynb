# %% [markdown]
# #### Create a new project in GITHUB

# %% [markdown]
# - create a repo in github(MyProject)

# %%
from IPython.display import Image
Image("F:\code\img\git1.png")

# %% [markdown]
# - copy the git repo link

# %%
from IPython.display import Image
Image("F:\code\img\git2.png")

# %% [markdown]
# - open file explorer and right click in the code folder and select "git bash here"

# %%
from IPython.display import Image
Image("F:\code\img\git3.png")
